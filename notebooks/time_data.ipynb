# %%
# %config Completer.use_jedi = False
import sys, IPython
print("IPython version:", IPython.__version__)
import jedi
print("Jedi version:", jedi.__version__)
# Out:
# IPython version: 9.8.0
# Jedi version: 0.19.2

# %%
import sys
import os
import numpy as np
import pandas as pd
import scanpy as sc
import anndata as ad
import tiledbsoma
import matplotlib.pyplot as plt
import seaborn as sns

# %%
path = "/fast/data/scTFM/ae/tiledb_all/SRX25263847"

# %%
experiment = tiledbsoma.Experiment.open(path)
ms = experiment.ms["RNA"]
ms
# Out:
# <Measurement 'file:///fast/data/scTFM/ae/tiledb_all/SRX25263847/ms/RNA' (open for 'r') (3 items)
#     'X': 'file:///fast/data/scTFM/ae/tiledb_all/SRX25263847/ms/RNA/X' (unopened)
#     'uns': 'file:///fast/data/scTFM/ae/tiledb_all/SRX25263847/ms/RNA/uns' (unopened)
#     'var': 'file:///fast/data/scTFM/ae/tiledb_all/SRX25263847/ms/RNA/var' (unopened)>

# %%
# 从实验对象读取obs数据
obs_df = experiment.obs.read().concat().to_pandas()
print(f"细胞观测数据加载完成: {obs_df.shape}")
print("列名:", list(obs_df.columns))
obs_df.head()
# Out:
# 细胞观测数据加载完成: (11495, 7)
# 列名: ['soma_joinid', 'obs_id', 'gene_count', 'umi_count', 'SRX_accession', 'n_genes', 'split_label']
#    soma_joinid            obs_id  gene_count  umi_count SRX_accession  \
# 0            0  AAACCCAAGGTCTACT        2699     6287.0   SRX25263847
# 1            1  AAACCCACAAGCTGCC        2442     7230.0   SRX25263847
# 2            2  AAACCCACAGAGGTTG        1732     3327.0   SRX25263847
# 3            3  AAACCCACAGGTGTTT         705     1392.0   SRX25263847
# 4            4  AAACCCAGTGCATTAC         759      988.0   SRX25263847
#
#    n_genes  split_label
# 0     2699            0
# 1     2442            0
# 2     1732            0
# 3      705            0
# 4      759            0

# %%
raw_path = "/fast/data/scTFM/ae/SRX25263847.h5ad"

adata = sc.read_h5ad(raw_path)
adata
# Out:
# AnnData object with n_obs × n_vars = 11530 × 36601
#     obs: 'gene_count', 'umi_count', 'SRX_accession'
#     var: 'gene_symbols', 'feature_types'

# %%
raw_path = "/fast/data/scTFM/rtf/TEDD/raw/Tedd_8_AdultVagina_scatac.h5ad"

adata = sc.read_h5ad(raw_path)
adata
# Out:
# AnnData object with n_obs × n_vars = 4824 × 13498
#     obs: 'Tissue', 'Celltype', 'Timepoint', 'Sex', 'UMAP_1', 'UMAP_2'
#     uns: 'Cell', 'PMID_DOI', 'Project', 'Sequencing', 'Species', 'Stage', 'Technology', 'Timepoint', 'Tissue'

# %%
SAMPLE_ID = "Tedd_22_FetalBoneMarrow"
SOMA_URI = f"/fast/data/scTFM/rtf/TEDD/tile_4000_fix/{SAMPLE_ID}"

# %%
experiment = tiledbsoma.Experiment.open(SOMA_URI)
ms = experiment.ms['RNA']
ms,experiment
# Out:
# (<Measurement 'file:///fast/data/scTFM/rtf/TEDD/tile_4000_fix/Tedd_22_FetalBoneMarrow/ms/RNA' (open for 'r') (6 items)
#      'X': 'file:///fast/data/scTFM/rtf/TEDD/tile_4000_fix/Tedd_22_FetalBoneMarrow/ms/RNA/X' (unopened)
#      'obsm': 'file:///fast/data/scTFM/rtf/TEDD/tile_4000_fix/Tedd_22_FetalBoneMarrow/ms/RNA/obsm' (unopened)
#      'obsp': 'file:///fast/data/scTFM/rtf/TEDD/tile_4000_fix/Tedd_22_FetalBoneMarrow/ms/RNA/obsp' (unopened)
#      'uns': 'file:///fast/data/scTFM/rtf/TEDD/tile_4000_fix/Tedd_22_FetalBoneMarrow/ms/RNA/uns' (unopened)
#      'var': 'file:///fast/data/scTFM/rtf/TEDD/tile_4000_fix/Tedd_22_FetalBoneMarrow/ms/RNA/var' (unopened)
#      'varm': 'file:///fast/data/scTFM/rtf/TEDD/tile_4000_fix/Tedd_22_FetalBoneMarrow/ms/RNA/varm' (unopened)>,
#  <Experiment '/fast/data/scTFM/rtf/TEDD/tile_4000_fix/Tedd_22_FetalBoneMarrow' (open for 'r') (2 items)
#      'ms': Collection 'file:///fast/data/scTFM/rtf/TEDD/tile_4000_fix/Tedd_22_FetalBoneMarrow/ms' (open for 'r') (1 item)
#          'RNA': Measurement 'file:///fast/data/scTFM/rtf/TEDD/tile_4000_fix/Tedd_22_FetalBoneMarrow/ms/RNA' (open for 'r') (6 items)
#              'X': 'file:///fast/data/scTFM/rtf/TEDD/tile_4000_fix/Tedd_22_FetalBoneMarrow/ms/RNA/X' (unopened)
#              'obsm': 'file:///fast/data/scTFM/rtf/TEDD/tile_4000_fix/Tedd_22_FetalBoneMarrow/ms/RNA/obsm' (unopened)
#              'obsp': 'file:///fast/data/scTFM/rtf/TEDD/tile_4000_fix/Tedd_22_FetalBoneMarrow/ms/RNA/obsp' (unopened)
#              'uns': 'file:///fast/data/scTFM/rtf/TEDD/tile_4000_fix/Tedd_22_FetalBoneMarrow/ms/RNA/uns' (unopened)
#              'var': 'file:///fast/data/scTFM/rtf/TEDD/tile_4000_fix/Tedd_22_FetalBoneMarrow/ms/RNA/var' (unopened)
#              'varm': 'file:///fast/data/scTFM/rtf/TEDD/tile_4000_fix/Tedd_22_FetalBoneMarrow/ms/RNA/varm' (unopened)
#      'obs': 'file:///fast/data/scTFM/rtf/TEDD/tile_4000_fix/Tedd_22_FetalBoneMarrow/obs' (unopened)>)

# %%
obs_df = experiment.obs.read().concat().to_pandas()
obs_df
# Out:
#         soma_joinid                                             obs_id  \
# 0                 0  Tedd_22_FetalBoneMarrow_F21_boneMarrow_CD45+_F...
# 1                 1  Tedd_22_FetalBoneMarrow_F21_boneMarrow_CD45+_F...
# 2                 2  Tedd_22_FetalBoneMarrow_F21_boneMarrow_CD45+_F...
# 3                 3  Tedd_22_FetalBoneMarrow_F21_boneMarrow_CD45+_F...
# 4                 4  Tedd_22_FetalBoneMarrow_F21_boneMarrow_CD45+_F...
# ...             ...                                                ...
# 103223       103223  Tedd_22_FetalBoneMarrow_TTTGGTTAGATGATTG-1-WSS...
# 103224       103224  Tedd_22_FetalBoneMarrow_TTTGGTTGTGGATCGA-1-WSS...
# 103225       103225  Tedd_22_FetalBoneMarrow_TTTGTTGAGTTGGCGA-1-WSS...
# 103226       103226  Tedd_22_FetalBoneMarrow_TTTGTTGTCAATGTCG-1-WSS...
# 103227       103227  Tedd_22_FetalBoneMarrow_TTTGTTGTCACCCTCA-1-WSS...
#
#              Tissue        Celltype Timepoint   Sex     UMAP_1     UMAP_2  \
# 0       Bone Marrow  Erythroid Cell      GW16  Male -13.130476  -0.022980
# 1       Bone Marrow          Stroma      GW16  Male   7.298230 -11.466713
# 2       Bone Marrow      Neutrophil      GW16  Male   2.022043   3.977409
# 3       Bone Marrow        Monocyte      GW16  Male  -1.699589  10.993606
# 4       Bone Marrow  Dendritic Cell      GW16  Male   6.611722 -11.464841
# ...             ...             ...       ...   ...        ...        ...
# 103223  Bone Marrow  Erythroid Cell   GW17-19  Male  -1.857476  -7.376513
# 103224  Bone Marrow      Neutrophil   GW17-19  Male  -0.739767   0.309046
# 103225  Bone Marrow  Erythroid Cell   GW17-19  Male  -6.605500  -4.846563
# 103226  Bone Marrow          B Cell   GW17-19  Male   6.117208   0.002200
# 103227  Bone Marrow          B Cell   GW17-19  Male   6.298948  -0.386781
#
#         time  n_genes  n_counts  \
# 0       16.0     5454   43788.0
# 1       16.0     3916   39292.0
# 2       16.0     3299   12187.0
# 3       16.0     2964   11849.0
# 4       16.0     4121   21819.0
# ...      ...      ...       ...
# 103223  18.0      657    3818.0
# 103224  18.0      535    1108.0
# 103225  18.0     1152   14325.0
# 103226  18.0     2630    8943.0
# 103227  18.0     1683    4459.0
#
#                                              next_cell_id  \
# 0       Tedd_22_FetalBoneMarrow_CAATGACTCGCATAGT-1-WSS...
# 1       Tedd_22_FetalBoneMarrow_CACACAAGTATGATCC-1-WSS...
# 2       Tedd_22_FetalBoneMarrow_TTGTTCATCGTAGTGT-1-WSS...
# 3       Tedd_22_FetalBoneMarrow_AAACGCTGTAATTAGG-1-WSS...
# 4       Tedd_22_FetalBoneMarrow_TCCGTGTTCTGGTTGA-1-WSS...
# ...                                                   ...
# 103223                                               None
# 103224                                               None
# 103225                                               None
# 103226                                               None
# 103227                                               None
#
#         next_cell_probability  \
# 0                    0.799996
# 1                    0.779780
# 2                    0.772415
# 3                    0.246583
# 4                    0.570798
# ...                       ...
# 103223               0.000000
# 103224               0.000000
# 103225               0.000000
# 103226               0.000000
# 103227               0.000000
#
#                                              prev_cell_id  \
# 0       Tedd_22_FetalBoneMarrow_F51_boneMarrow_CD45+_F...
# 1       Tedd_22_FetalBoneMarrow_F51_boneMarrow_CD45+_F...
# 2       Tedd_22_FetalBoneMarrow_F30_boneMarrow_CD45+_F...
# 3       Tedd_22_FetalBoneMarrow_F30_boneMarrow_CD45+_F...
# 4       Tedd_22_FetalBoneMarrow_F30_boneMarrow_CD45+_F...
# ...                                                   ...
# 103223  Tedd_22_FetalBoneMarrow_F41_boneMarrow_CD45-_F...
# 103224  Tedd_22_FetalBoneMarrow_F41_boneMarrow_CD45-_F...
# 103225  Tedd_22_FetalBoneMarrow_F29_boneMarrow_CD45+_F...
# 103226  Tedd_22_FetalBoneMarrow_F41_boneMarrow_CD45+_F...
# 103227  Tedd_22_FetalBoneMarrow_F41_boneMarrow_CD45+_F...
#
#         prev_cell_probability  split_label
# 0                7.984712e-01            0
# 1                7.922889e-01            0
# 2                4.963417e-01            0
# 3                7.806604e-01            0
# 4                6.009362e-02            0
# ...                       ...          ...
# 103223           2.129699e-02            0
# 103224           3.791386e-11            0
# 103225           2.261113e-01            0
# 103226           1.574261e-01            0
# 103227           1.649096e-04            0
#
# [103228 rows x 16 columns]

# %%
uns_df = ms.uns.read().concat().to_pandas()
uns_df
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[38], line 1
# ----> 1 uns_df = experiment.uns.read().concat().to_pandas()
#       2 uns_df
#
# AttributeError: 'Experiment' object has no attribute 'uns'
